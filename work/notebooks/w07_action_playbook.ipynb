# %% [markdown]
# # ML-10 — Action Playbook and Prioritized Refresh Queue
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This notebook translates model probability outputs into actionable business recommendations and ranked queue exports.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

ROOT = Path('.').resolve()
while not (ROOT / 'data').exists() and ROOT.parent != ROOT:
    ROOT = ROOT.parent

# Load pipeline outputs
queue_path = ROOT / 'outputs' / 'refresh_queue.csv'
if queue_path.exists():
    queue_df = pd.read_csv(queue_path)
    print(f"Loaded generated refresh queue: {len(queue_df):,} rows")
    print("\nTop 5 High-Priority Refresh Recommendations:")
    # Support both column schemas safely
    target_cols = ['final_rank', 'content_id', 'best_model_probability', 'suggested_action', 'final_reason_codes']
    avail_cols = [c for c in target_cols if c in queue_df.columns]
    if not avail_cols:
        avail_cols = queue_df.columns[:5].tolist()
    print(queue_df[avail_cols].head(5).to_string(index=False))
else:
    print("Refresh queue ready for export.")
# Out:
# Loaded generated refresh queue: 30,000 rows
#
# Top 5 High-Priority Refresh Recommendations:
#  final_rank           content_id  best_model_probability       suggested_action                                                                                                                                                   final_reason_codes
#           1 content_1f080331fa2b                0.783472 refresh_and_review_ctr declining_with_demand|low_ctr_visible_page|low_engagement_visible_page|model_decline_risk|visible_model_opportunity|ctr_review_candidate|engagement_review_candidate
#           2 content_d6570c51c9bd                0.849842 refresh_and_review_ctr                                                         declining_with_demand|low_ctr_visible_page|model_decline_risk|visible_model_opportunity|ctr_review_candidate
#           3 content_6aa43079fb0c                0.789490 refresh_and_review_ctr                                                         declining_with_demand|low_ctr_visible_page|model_decline_risk|visible_model_opportunity|ctr_review_candidate
#           4 content_72e800a9c214                0.776297 refresh_and_review_ctr                                                         declining_with_demand|low_ctr_visible_page|model_decline_risk|visible_model_opportunity|ctr_review_candidate
#           5 content_e04eb9549989                0.816010 refresh_and_review_ctr                                                         declining_with_demand|low_ctr_visible_page|model_decline_risk|visible_model_opportunity|ctr_review_candidate
